# %% [markdown]
# LIBRERIAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm # type: ignore
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Out:
# c:\Users\Equipo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.1)
#   from scipy.stats import gaussian_kde

# %% [markdown]
# CARGA DEL DATASET

# %%
#ruta = "C:/Users/Equipo/Documents/Mis_Codigos/Circulo_de_lectura_Alice/Capitulo_4_Reg_Logistica/Personalidad.csv"
ruta = ".\Personalidad.csv"
datos = pd.read_csv(ruta, encoding = 'utf-8')
datos.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                 4         No                        4              6
# 1                 9        Yes                        0              0
# 2                 9        Yes                        1              2
# 3                 0         No                        6              7
# 4                 3         No                        9              4
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                        No                   13               5            1
# 1                       Yes                    0               3            0
# 2                       Yes                    5               2            0
# 3                        No                   14               8            1
# 4                        No                    8               5            1

# %%
datos.describe()
# Out:
#        Time_spent_Alone  Social_event_attendance  Going_outside  \
# count       2776.000000              2776.000000    2776.000000
# mean           4.497478                 3.947406       2.998919
# std            3.444697                 2.871313       2.224272
# min            0.000000                 0.000000       0.000000
# 25%            2.000000                 2.000000       1.000000
# 50%            4.000000                 3.000000       3.000000
# 75%            7.000000                 6.000000       5.000000
# max           11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency  Personality
# count          2776.000000     2776.000000   2776.00000
# mean              6.227666        3.554035      0.51549
# std               4.242306        2.892295      0.49985
# min               0.000000        0.000000      0.00000
# 25%               3.000000        1.000000      0.00000
# 50%               5.000000        3.000000      1.00000
# 75%              10.000000        6.000000      1.00000
# max              15.000000       10.000000      1.00000

# %% [markdown]
# Como ya estoy usando un dataset que limpie y explore voy a saltear estos pocesos y me voy a enfocar en aplicar los modelos.

# %% [markdown]
# Acondicionamiento de los datos

# %%
datos_encoded = datos.copy()

# %%
datos_encoded = pd.get_dummies(datos_encoded, columns=['Stage_fear', 'Drained_after_socializing'])
datos_encoded.head()
# Out:
#    Time_spent_Alone  Social_event_attendance  Going_outside  \
# 0                 4                        4              6
# 1                 9                        0              0
# 2                 9                        1              2
# 3                 0                        6              7
# 4                 3                        9              4
#
#    Friends_circle_size  Post_frequency  Personality  Stage_fear_No  \
# 0                   13               5            1           True
# 1                    0               3            0          False
# 2                    5               2            0          False
# 3                   14               8            1           True
# 4                    8               5            1           True
#
#    Stage_fear_Yes  Drained_after_socializing_No  Drained_after_socializing_Yes
# 0           False                          True                          False
# 1            True                         False                           True
# 2            True                         False                           True
# 3           False                          True                          False
# 4           False                          True                          False

# %%
datos_encoded = datos_encoded.astype(int)

# %%
datos_encoded["Personality"] = pd.to_numeric(datos_encoded["Personality"], errors="coerce")
datos_encoded.head()
# Out:
#    Time_spent_Alone  Social_event_attendance  Going_outside  \
# 0                 4                        4              6
# 1                 9                        0              0
# 2                 9                        1              2
# 3                 0                        6              7
# 4                 3                        9              4
#
#    Friends_circle_size  Post_frequency  Personality  Stage_fear_No  \
# 0                   13               5            1              1
# 1                    0               3            0              0
# 2                    5               2            0              0
# 3                   14               8            1              1
# 4                    8               5            1              1
#
#    Stage_fear_Yes  Drained_after_socializing_No  Drained_after_socializing_Yes
# 0               0                             1                              0
# 1               1                             0                              1
# 2               1                             0                              1
# 3               0                             1                              0
# 4               0                             1                              0

# %%
datos_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2776 entries, 0 to 2775
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Time_spent_Alone               2776 non-null   int64
#  1   Social_event_attendance        2776 non-null   int64
#  2   Going_outside                  2776 non-null   int64
#  3   Friends_circle_size            2776 non-null   int64
#  4   Post_frequency                 2776 non-null   int64
#  5   Personality                    2776 non-null   int64
#  6   Stage_fear_No                  2776 non-null   int64
#  7   Stage_fear_Yes                 2776 non-null   int64
#  8   Drained_after_socializing_No   2776 non-null   int64
#  9   Drained_after_socializing_Yes  2776 non-null   int64
# dtypes: int64(10)
# memory usage: 217.0 KB

# %% [markdown]
# Tratamiento de variables no numericas

# %%
y = datos_encoded["Personality"]
X = datos_encoded.drop(["Drained_after_socializing_Yes", "Stage_fear_No", "Stage_fear_Yes", "Personality"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) #Si incremento el random_state mejora

# %%
print('La forma de X_train es: ', X_train.shape)
print('La forma de y_train es: ', y_train.shape)
print('La forma de X_test es: ', X_test.shape)
print('La forma de y_test es: ', y_test.shape)
# Out:
# La forma de X_train es:  (1943, 6)
# La forma de y_train es:  (1943,)
# La forma de X_test es:  (833, 6)
# La forma de y_test es:  (833,)

# %% [markdown]
# Declaración del modelo y entrenamiento

# %%
clasificador = LogisticRegression(random_state=0)
clasificador.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# Predicion (testeo)

# %%
y_pred = clasificador.predict(X_test)

# %% [markdown]
# Metricas

# %%
cm = confusion_matrix(y_test, y_pred)
print("Matriz de confusión:")
print(cm)

print("Metricas de la clasificación")
print(classification_report(y_test, y_pred))
# Out:
# Matriz de confusión:
# [[386  19]
#  [ 31 397]]
# Metricas de la clasificación
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       405
#            1       0.95      0.93      0.94       428
#
#     accuracy                           0.94       833
#    macro avg       0.94      0.94      0.94       833
# weighted avg       0.94      0.94      0.94       833

# %%
class_names=[0,1] 
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted label')

# %%
y_pred_proba = clasificador.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# Metricas de las variables independientes

# %%
#Añade una columna de unos para que el modelo incluya un término independiente o intercepto (β₀) en la regresión logística
X_constant = sm.add_constant(X)
print("Columnas:", X_constant.shape[1])
#Calcula cuantas columnas son linealmente independientes.
print("Rango de la matriz:", np.linalg.matrix_rank(X_constant))
# Out:
# Columnas: 7
# Rango de la matriz: 7

# %%
#Esto muestra una matriz de correlación entre todas las variables predictoras
#pd.DataFrame(X_constant).corr()
pd.DataFrame(X_constant.drop(columns='const')).corr()
# Out:
#                               Time_spent_Alone  Social_event_attendance  \
# Time_spent_Alone                      1.000000                -0.718125
# Social_event_attendance              -0.718125                 1.000000
# Going_outside                        -0.736835                 0.732326
# Friends_circle_size                  -0.700808                 0.717090
# Post_frequency                       -0.718477                 0.727339
# Drained_after_socializing_No         -0.850790                 0.849930
#
#                               Going_outside  Friends_circle_size  \
# Time_spent_Alone                  -0.736835            -0.700808
# Social_event_attendance            0.732326             0.717090
# Going_outside                      1.000000             0.718338
# Friends_circle_size                0.718338             1.000000
# Post_frequency                     0.755739             0.688410
# Drained_after_socializing_No       0.872637             0.822904
#
#                               Post_frequency  Drained_after_socializing_No
# Time_spent_Alone                   -0.718477                     -0.850790
# Social_event_attendance             0.727339                      0.849930
# Going_outside                       0.755739                      0.872637
# Friends_circle_size                 0.688410                      0.822904
# Post_frequency                      1.000000                      0.842849
# Drained_after_socializing_No        0.842849                      1.000000

# %%
modelo = sm.Logit(y, X_constant)
resultado = modelo.fit()
print(resultado.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.230408
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            Personality   No. Observations:                 2776
# Model:                          Logit   Df Residuals:                     2769
# Method:                           MLE   Df Model:                            6
# Date:                Sat, 05 Jul 2025   Pseudo R-squ.:                  0.6674
# Time:                        14:33:47   Log-Likelihood:                -639.61
# converged:                       True   LL-Null:                       -1922.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           -3.0775      0.396     -7.763      0.000      -3.855      -2.300
# Time_spent_Alone                 0.2312      0.044      5.297      0.000       0.146       0.317
# Social_event_attendance         -0.1963      0.055     -3.593      0.000      -0.303      -0.089
# Going_outside                   -0.3211      0.076     -4.253      0.000      -0.469      -0.173
# Friends_circle_size             -0.1957      0.036     -5.428      0.000      -0.266      -0.125
# Post_frequency                  -0.1141      0.054     -2.131      0.033      -0.219      -0.009
# Drained_after_socializing_No    11.2718      0.719     15.682      0.000       9.863      12.681
# ================================================================================================

# %% [markdown]
# Gráfica de la función de perdida (Variable Time_spend_alone)

# %%
parametro_indice = 1
paramentro_rango = np.linspace(resultado.params[parametro_indice]-2, resultado.params[parametro_indice]+2,100)

perdida_valores = []

for val in paramentro_rango:
    parametros = resultado.params.copy()
    parametros[parametro_indice] = val
    
    peridida = -modelo.loglike(parametros)
    perdida_valores.append(peridida)

plt.plot(paramentro_rango, perdida_valores)
plt.xlabel(f'Valor del coeficiente {X_constant.columns[parametro_indice]}')
plt.ylabel('Función de pérdida (log-likelihood negativo)')
plt.title('Curva de la función de pérdida')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Equipo\AppData\Local\Temp\ipykernel_14656\1547108883.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   paramentro_rango = np.linspace(resultado.params[parametro_indice]-2, resultado.params[parametro_indice]+2,100)
# C:\Users\Equipo\AppData\Local\Temp\ipykernel_14656\1547108883.py:8: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   parametros[parametro_indice] = val

# %% [markdown]
# Gráfica de la función de perdida (Variable Going_outside)

# %%
parametro_indice = 3
paramentro_rango = np.linspace(resultado.params[parametro_indice]-2, resultado.params[parametro_indice]+2,100)

perdida_valores = []

for val in paramentro_rango:
    parametros = resultado.params.copy()
    parametros[parametro_indice] = val
    
    peridida = -modelo.loglike(parametros)
    perdida_valores.append(peridida)

plt.plot(paramentro_rango, perdida_valores)
plt.xlabel(f'Valor del coeficiente {X_constant.columns[parametro_indice]}')
plt.ylabel('Función de pérdida (log-likelihood negativo)')
plt.title('Curva de la función de pérdida')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Equipo\AppData\Local\Temp\ipykernel_14656\2804591568.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   paramentro_rango = np.linspace(resultado.params[parametro_indice]-2, resultado.params[parametro_indice]+2,100)
# C:\Users\Equipo\AppData\Local\Temp\ipykernel_14656\2804591568.py:8: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   parametros[parametro_indice] = val
